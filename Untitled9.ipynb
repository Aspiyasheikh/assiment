# %% [markdown]
# Q1. What are Eigenvectors? How are they related to the Eigen-Decomposition approach?

# %% [markdown]
# Ans: What are Eigenvectors?
# Eigenvectors are directions in which a linear transformation only stretches or compresses the data — their direction doesn’t change.
#
# They come with eigenvalues, which tell you how much they stretch or shrink.
#
#  Equation:
# A · v = λ · v
#
# A = square matrix
#
# v = eigenvector
#
# λ = eigenvalue
#
#  What is Eigen-Decomposition?
# It's a method to break down a matrix into its eigenvectors and eigenvalues.
#
# Formula:
# A = V · Λ · V⁻¹
# Where:
#
# V = matrix of eigenvectors
#
# Λ = diagonal matrix of eigenvalues
#
#  Relation:
# Eigen-decomposition finds the eigenvectors (directions) and eigenvalues (importance) of a matrix.
#
# In PCA, this helps to identify the principal components (most informative directions in the data)

# %% [markdown]
# Q2. What is eigen decomposition and what is its significance in linear algebra?

# %% [markdown]
# Ans: What is Eigen Decomposition?
# Eigen decomposition is a technique in linear algebra where a square matrix is broken into its eigenvectors and eigenvalues.
#
#  Formula:
# A = V · Λ · V⁻¹
#
# A: original square matrix
#
# V: matrix of eigenvectors
#
# Λ: diagonal matrix of eigenvalues
#
# V⁻¹: inverse of eigenvector matrix
#
#  Significance in Linear Algebra:
# Simplifies Matrix Operations
#
# Makes it easier to compute powers of matrices:
# Aⁿ = V · Λⁿ · V⁻¹
#
# Foundation for PCA
#
# PCA uses eigen decomposition on the covariance matrix to find principal components.
#
# Reveals Matrix Structure
#
# Shows the directions (eigenvectors) along which the transformation acts, and how strongly (eigenvalues).
#
# Used in Stability Analysis
#
# In systems (e.g., differential equations), eigenvalues help determine system behavior.

# %% [markdown]
# Q3. What are the condition that must be satisfied for a square matrix to be diagonalizable using the Eigen-Decomposition approach?Provide a brief proof to support your answer.

# %% [markdown]
# Ans: To diagonalize a square matrix
# 𝐴
# A using the Eigen-Decomposition approach, the following condition must be satisfied:
#
# ✅ Condition:
# A square matrix
# 𝐴
# ∈
# 𝑅
# 𝑛
# ×
# 𝑛
# A∈R
# n×n
#   is diagonalizable if and only if it has
# 𝑛
# n linearly independent eigenvectors.
#
# 🔁 Equivalent condition:
# This is equivalent to saying:
#
# The geometric multiplicity (number of linearly independent eigenvectors) of each eigenvalue must equal its algebraic multiplicity (its multiplicity as a root of the characteristic polynomial).
#
# 📌 Why? (Brief Proof)
# Let’s say
# 𝐴
# A is diagonalizable. Then:
#
# There exists an invertible matrix
# 𝑃
# P and a diagonal matrix
# 𝐷
# D such that:
#
# 𝐴
# =
# 𝑃
# 𝐷
# 𝑃
# −
# 1
# A=PDP
# −1
#
# Now,
#
# ⇒
# 𝐴
# 𝑃
# =
# 𝑃
# 𝐷
# ⇒AP=PD
# Let the columns of
# 𝑃
# P be the eigenvectors of
# 𝐴
# A, and the diagonal entries of
# 𝐷
# D be the corresponding eigenvalues.
#
# This means:
#
# 𝐴
# 𝑣
# ⃗
# 𝑖
# =
# 𝜆
# 𝑖
# 𝑣
# ⃗
# 𝑖
# for each
# 𝑖
# =
# 1
# ,
# 2
# ,
# .
# .
# .
# ,
# 𝑛
# A
# v
#
# i
# ​
#  =λ
# i
# ​
#
# v
#
# i
# ​
#  for each i=1,2,...,n
# So, for diagonalization to be possible:
#
# ✅ You must have
# 𝑛
# n linearly independent eigenvectors (which form the matrix
# 𝑃
# P).
#
# 🚫 If not diagonalizable?
# If
# 𝐴
# A has fewer than
# 𝑛
# n linearly independent eigenvectors, you cannot construct the matrix
# 𝑃
# P, and
# 𝐴
# A is not diagonalizable.
#
#  Example (Diagonalizable Matrix):
# 𝐴
# =
# [
# 2
# 0
# 0
# 3
# ]
# A=[
# 2
# 0
# ​
#
# 0
# 3
# ​
#  ]
# Eigenvalues: 2 and 3
#
# Two distinct eigenvalues ⇒ 2 independent eigenvectors
#  Diagonalizable
#
#  Example (Not Diagonalizable):
# 𝐴
# =
# [
# 1
# 1
# 0
# 1
# ]
# A=[
# 1
# 0
# ​
#
# 1
# 1
# ​
#  ]
# One eigenvalue: 1 (with algebraic multiplicity 2)
#
# Only one linearly independent eigenvector
#  Not diagonalizable

# %% [markdown]
# Q4. What is the singificance of the spectral theorem in the context of the Eigen-Decomposition approach? How is it related to the diagonalizability of a matrix?Explain with an example?

# %% [markdown]
# Ans:  Spectral Theorem (Inshort)
# Applies to: Real symmetric matrices
#
# Says: Such matrices are always diagonalizable with orthonormal eigenvectors
#
# 𝐴
# =
# 𝑄
# Λ
# 𝑄
# 𝑇
# A=QΛQ
# T
#
# Where:
#
# 𝑄
# Q = matrix of orthonormal eigenvectors
#
# Λ
# Λ = diagonal matrix of real eigenvalues
#
# 🎯 Significance:
# Guarantees diagonalizability
#
# Ensures real eigenvalues
#
# Makes computations (like PCA) easier and more stable
#
# 📌 Example:
# For
#
# 𝐴
# =
# [
# 4
# 1
# 1
# 4
# ]
# A=[
# 4
# 1
# ​
#
# 1
# 4
# ​
#  ]
# → Real symmetric ⇒ Spectral theorem applies
# → Eigenvalues: 3 and 5
# → Orthonormal eigenvectors form matrix
# 𝑄
# Q
#
# ✅ So:
#
# 𝐴
# =
# 𝑄
# Λ
# 𝑄
# 𝑇
# A=QΛQ
# T

# %% [markdown]
# Q5. How do you find the eigenvalues of a matrix and what do they represent?

# %% [markdown]
# Ans: Eigenvalues represent scaling factors by which an eigenvector is stretched or shrunk during a linear transformation.
#
# If
# 𝐴
# 𝑥
# ⃗
# =
# 𝜆
# 𝑥
# ⃗
# A
# x
#  =λ
# x
#  , it means vector
# 𝑥
# ⃗
# x
#   does not change direction, only its length changes by factor
# 𝜆
# λ.
#
# 🔧 Example:
# Let
#
# 𝐴
# =
# [
# 2
# 1
# 1
# 2
# ]
# A=[
# 2
# 1
# ​
#
# 1
# 2
# ​
#  ]
# Step 1:
#
# det
# ⁡
# (
# 𝐴
# −
# 𝜆
# 𝐼
# )
# =
# ∣
# 2
# −
# 𝜆
# 1
# 1
# 2
# −
# 𝜆
# ∣
# =
# (
# 2
# −
# 𝜆
# )
# 2
# −
# 1
# =
# 0
# det(A−λI)=
# ​
#
# 2−λ
# 1
# ​
#
# 1
# 2−λ
# ​
#
# ​
#  =(2−λ)
# 2
#  −1=0
# Step 2:
#
# 𝜆
# 2
# −
# 4
# 𝜆
# +
# 3
# =
# 0
# ⇒
# 𝜆
# =
# 1
# ,
# 3
# λ
# 2
#  −4λ+3=0⇒λ=1,3
# ✅ Eigenvalues = 1 and 3
#
# ✨ Intuition:
# A transformation by
# 𝐴
# A scales some vectors by 1 (no change) and others by 3 (stretching them).
#
# These special vectors are called eigenvectors.

# %% [markdown]
# Q6.What are eigenvectors and how are they related to eigenvalues?

# %% [markdown]
# Ans: Eigenvectors:
# An eigenvector of a square matrix
# 𝐴
# A is a non-zero vector
# 𝑥
# ⃗
# x
#   that satisfies:
#
# 𝐴
# 𝑥
# ⃗
# =
# 𝜆
# 𝑥
# ⃗
# A
# x
#  =λ
# x
#
# Where:
#
# 𝜆
# λ is the eigenvalue corresponding to eigenvector
# 𝑥
# ⃗
# x
#
#
# 🔗 Relation to Eigenvalues:
# Eigenvalues (
# 𝜆
# λ) are scalars that show how much the eigenvector is stretched or compressed during the transformation.
#
# The direction of the eigenvector doesn't change — only its magnitude (by a factor of
# 𝜆
# λ).
#
# 🔁 Summary of the Relationship:
# Term	Meaning
# Eigenvalue
# 𝜆
# λ	Scaling factor for the transformation
# Eigenvector
# 𝑥
# ⃗
# x
#  	Direction that remains unchanged (only scaled)
# Equation
# 𝐴
# 𝑥
# ⃗
# =
# 𝜆
# 𝑥
# ⃗
# A
# x
#  =λ
# x
#
# 📌 Example:
# Let
#
# 𝐴
# =
# [
# 2
# 0
# 0
# 3
# ]
# A=[
# 2
# 0
# ​
#
# 0
# 3
# ​
#  ]
# Eigenvalue
# 𝜆
# =
# 2
# λ=2 → eigenvector along
# 𝑥
# x-axis (e.g.,
# [
# 1
# ,
# 0
# ]
# 𝑇
# [1,0]
# T
#  )
#
# Eigenvalue
# 𝜆
# =
# 3
# λ=3 → eigenvector along
# 𝑦
# y-axis (e.g.,
# [
# 0
# ,
# 1
# ]
# 𝑇
# [0,1]
# T
#  )
#
# ✅ These vectors are stretched by factors 2 and 3, respectively.

# %% [markdown]
# Q7. Can you explain the geometric interpretation of eigenvectors and eigenvalues?

# %% [markdown]
# Ans: Eigenvectors (Direction):
# Eigenvectors are directions in space that don’t change when a matrix transformation is applied.
#
# They stay on the same line — only stretched, compressed, or flipped.
#
# 📏 Eigenvalues (Scaling):
# The eigenvalue
# 𝜆
# λ tells how much the corresponding eigenvector is stretched or shrunk.
#
# 𝜆
# >
# 1
# λ>1: stretched
#
# 0
# <
# 𝜆
# <
# 1
# 0<λ<1: compressed
#
# 𝜆
# <
# 0
# λ<0: flipped direction
#
# 📐 Visualization (2D Example):
# Let
#
# 𝐴
# =
# [
# 2
# 1
# 1
# 2
# ]
# A=[
# 2
# 1
# ​
#
# 1
# 2
# ​
#  ]
# Apply
# 𝐴
# A to a bunch of 2D vectors → most vectors change direction.
#
# But a few special vectors (the eigenvectors) just get scaled.
#
# For example:
#
# Eigenvector:
# 𝑥
# ⃗
# =
# [
# 1
# 1
# ]
# x
#  =[
# 1
# 1
# ​
#  ]
#
# Eigenvalue:
# 𝜆
# =
# 3
# λ=3
#
# 𝐴
# 𝑥
# ⃗
# =
# 3
# 𝑥
# ⃗
# A
# x
#  =3
# x
#   → vector stretched, no change in direction.

# %% [markdown]
# Q8. What are some real-world applications of eigen decomposition?

# %% [markdown]
# Ans:  Principal Component Analysis (PCA)
# Purpose: Dimensionality reduction
#
# How: Eigen decomposition of the covariance matrix
#
# Result: Finds directions (eigenvectors) that capture the most variance (eigenvalues)
#
#  2. Face Recognition (e.g., Eigenfaces)
# Faces are represented as vectors
#
# PCA is used to find eigenfaces → compact and unique features
#
# Speeds up and improves accuracy in face detection systems
#
#  3. Computer Graphics / Animation
# Used to understand object transformations (scaling, rotation)
#
# Helps in physically based simulations like deforming objects
#
#  4. Molecular Vibrations (Quantum Chemistry)
# Eigenvalues: vibration frequencies
#
# Eigenvectors: vibration modes of atoms in molecules
#
#  5. Google PageRank
# Web is modeled as a matrix
#
# Eigenvector of the link matrix tells importance of each webpage
#
# Used to rank search results

# %% [markdown]
# Q9. Can a matrix have more than one set of eigenvectors and eigenvalues?

# %% [markdown]
# Ans: Eigenvalues:
# A matrix has only one set of eigenvalues (up to order).
# However, some eigenvalues can be repeated — this is called multiplicity.
#
# 🔹 Eigenvectors:
# A matrix can have multiple sets of eigenvectors depending on:
#
# The number of distinct eigenvalues
#
# Whether the matrix is diagonalizable
#
# ➡️ For each eigenvalue, there can be one or more linearly independent eigenvectors.
#
# 📌 Example:
# Matrix:
#
# 𝐴
# =
# [
# 2
# 0
# 0
# 2
# ]
# A=[
# 2
# 0
# ​
#
# 0
# 2
# ​
#  ]
# Eigenvalue:
# 𝜆
# =
# 2
# λ=2 (with multiplicity 2)
#
# Eigenvectors: Any non-zero vector in
# 𝑅
# 2
# R
# 2
#   (like
# [
# 1
# ,
# 0
# ]
# 𝑇
# [1,0]
# T
#  ,
# [
# 0
# ,
# 1
# ]
# 𝑇
# [0,1]
# T
#  , etc.)
# ✅ So, infinitely many eigenvectors are possible.

# %% [markdown]
# Q10. In what ways is the Eigen-Decomposition approach useful in data analysis and machine learning? Discuss at least three specific applications or techniques that rely on Eigen-Dexomposition.

# %% [markdown]
# Ans:  1. PCA (Principal Component Analysis)
# 👉 Reduces dimensionality by selecting top eigenvectors of the covariance matrix
# 👉 Helps with data compression, noise reduction, and visualization
#
# 🔹 2. Spectral Clustering
# 👉 Builds a similarity graph → gets eigenvectors of the Laplacian matrix
# 👉 Clusters complex or non-convex shaped data more effectively
#
# 🔹 3. LSA (Latent Semantic Analysis)
# 👉 Decomposes the term-document matrix
# 👉 Finds hidden meanings or topics in text data (used in NLP, search engines)
#
# 🔹 4. Image Compression (e.g., Eigenfaces)
# 👉 Uses eigenvectors of face image matrices to reduce image size while preserving features
#
# 🔹 5. Portfolio Optimization (Finance)
# 👉 Eigenvalues of the covariance matrix of asset returns help manage risk & diversification
